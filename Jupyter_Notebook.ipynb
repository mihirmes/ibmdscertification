# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # IBM Tools for Data Science Peer Graded Assignment

# %% [markdown]
# ##### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ##### Python, Ruby, R

# %% [markdown]
# ##### Python: sci-kit learn, tensorflow, keras, pandas, numpy

# %% [markdown]
# | Tool | Examples |
# | --- | --- |
# | Languages | Python, Ruby, R, Java, SQL |
# | Libraries | Sci-kit learn, SciPy, Keras, TensorFlow, Pandas, NumPy |

# %% [markdown]
# ### Below are a few examples of arithmetic operations

# %%
# This is a simple arithmetic operation
(3*4)+5
# Out:
# 17

# %%
# this will convert 200 miunutes to hours
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# __Objectives__:
#  - popular ds languages
#  - popular ds libraries
#  - multiplication and addition of numbers
#  - division of numbers

# %% [markdown]
# ## Author
# Mihir Meswania
